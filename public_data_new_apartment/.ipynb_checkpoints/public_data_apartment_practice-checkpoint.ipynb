# %% [markdown]
# # 전국 신규 민간 아파트 분양 가격 동향

# %%
# base
import os
import numpy as np
import pandas as pd
import seaborn as sns
import missingno as msno
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
# 정규표현식
import re

# plotnine
from plotnine import *
import plotnine

# %%
# 그래프에서 한글표현을 위한 폰트 설치
# %config InlineBackend.figure_format = 'retina'

import matplotlib.font_manager as fm

fontpath = '/Library/Fonts/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)

# %%
# 기본 글꼴 변경
import matplotlib as mpl

mpl.font_manager._rebuild()
mpl.pyplot.rc('font', family='NanumBarunGothic')

# 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# # Data Load

# %%
print(os.listdir("data/"))
# Out:
# ['.DS_Store', 'raw.csv', '2018_06_national_avg_pirce.csv', '2013_09_2015_09_national_avg_pirce.csv']

# %%
data_1806 = pd.read_csv("data/2018_06_national_avg_pirce.csv", encoding='euc-kr')
print(data_1806.shape)
# Out:
# (2805, 5)

# %% [markdown]
# # Null Check

# %%
msno.matrix(data_1806, figsize=(6, 3))

# %%
data_1806.isnull().sum()
# Out:
# 지역명          0
# 규모구분         0
# 연도           0
# 월            0
# 분양가격(㎡)    147
# dtype: int64

# %%
data_1806.head()
# Out:
#   지역명               규모구분    연도   월  분양가격(㎡)
# 0  서울                 전체  2015  10   5841.0
# 1  서울         전용면적 60㎡이하  2015  10   5652.0
# 2  서울   전용면적 60㎡초과 85㎡이하  2015  10   5882.0
# 3  서울  전용면적 85㎡초과 102㎡이하  2015  10   5721.0
# 4  서울        전용면적 102㎡초과  2015  10   5879.0

# %% [markdown]
# # Data Processing

# %%
data_1806.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2805 entries, 0 to 2804
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지역명      2805 non-null   object
#  1   규모구분     2805 non-null   object
#  2   연도       2805 non-null   int64
#  3   월        2805 non-null   int64
#  4   분양가격(㎡)  2658 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 109.7+ KB

# %%
data_1806["연도"] = data_1806["연도"].astype(str)
data_1806["월"] = data_1806["월"].astype(str)

# %%
data_1806["평당분양가격"] = data_1806["분양가격(㎡)"] * 3.3

data_1806.head()
# Out:
#   지역명               규모구분    연도   월  분양가격(㎡)   평당분양가격
# 0  서울                 전체  2015  10   5841.0  19275.3
# 1  서울         전용면적 60㎡이하  2015  10   5652.0  18651.6
# 2  서울   전용면적 60㎡초과 85㎡이하  2015  10   5882.0  19410.6
# 3  서울  전용면적 85㎡초과 102㎡이하  2015  10   5721.0  18879.3
# 4  서울        전용면적 102㎡초과  2015  10   5879.0  19400.7

# %%
data_1806.describe()
# Out:
#            분양가격(㎡)        평당분양가격
# count  2658.000000   2658.000000
# mean   3060.279533  10098.922460
# std    1111.300681   3667.292246
# min    1868.000000   6164.400000
# 25%    2345.250000   7739.325000
# 50%    2743.000000   9051.900000
# 75%    3300.750000  10892.475000
# max    8098.000000  26723.400000

# %%
data_1806.describe(include=[np.object])
# Out:
#          지역명        규모구분    연도     월
# count   2805        2805  2805  2805
# unique    17           5     4    12
# top       충남  전용면적 60㎡이하  2016     2
# freq     165         561  1020   255

# %%
data_1806_2017 = data_1806.loc[data_1806["연도"] == "2017"]
print(data_1806_2017.shape)
# Out:
# (1020, 6)

# %%
data_1806["규모구분"].value_counts()
# Out:
# 전용면적 60㎡이하           561
# 전용면적 85㎡초과 102㎡이하    561
# 전용면적 102㎡초과          561
# 전용면적 60㎡초과 85㎡이하     561
# 전체                   561
# Name: 규모구분, dtype: int64

# %% [markdown]
# # 전국 평균 분양가격

# %%
pd.options.display.float_format = '{:,.0f}'.format
data_1806.groupby(data_1806.연도).describe().T
# Out:
# 연도              2015   2016   2017   2018
# 분양가격(㎡) count    243    984    975    456
#         mean   2,789  2,934  3,143  3,299
#         std      977  1,071  1,111  1,199
#         min    1,868  1,900  1,976  2,076
#         25%    2,225  2,282  2,373  2,470
#         50%    2,516  2,672  2,838  2,912
#         75%    3,026  3,148  3,466  3,647
#         max    7,092  8,096  7,887  8,098
# 평당분양가격  count    243    984    975    456
#         mean   9,203  9,683 10,373 10,888
#         std    3,224  3,536  3,665  3,958
#         min    6,164  6,270  6,521  6,851
#         25%    7,342  7,531  7,831  8,153
#         50%    8,303  8,818  9,365  9,611
#         75%    9,984 10,390 11,438 12,036
#         max   23,404 26,717 26,027 26,723

# %% [markdown]
# # 규모별 전국평균 분양 가격

# %%
data_1806.pivot_table("평당분양가격", "규모구분", "연도")
# Out:
# 연도                 2015   2016   2017   2018
# 규모구분
# 전용면적 102㎡초과       9,837 10,389 11,311 11,260
# 전용면적 60㎡이하        8,952  9,399 10,271 10,957
# 전용면적 60㎡초과 85㎡이하  8,892  9,296  9,840 10,438
# 전용면적 85㎡초과 102㎡이하 9,519 10,122 10,573 11,457
# 전체                8,893  9,293  9,927 10,560

# %% [markdown]
# # 전국 분양가 변동금액

# %%
region_year_all = data_1806.loc[data_1806["규모구분"] == "전체"]
region_year = region_year_all.pivot_table("평당분양가격", "지역명", "연도").reset_index()
region_year
# Out:
# 연도 지역명   2015   2016   2017   2018
# 0   강원  7,160  7,011  7,171  7,643
# 1   경기 10,377 11,220 11,841 12,854
# 2   경남  7,586  7,848  8,164  8,894
# 3   경북  7,171  7,361  7,803  8,262
# 4   광주  8,052  8,899  9,471  9,630
# 5   대구  9,232 10,310 11,507 11,652
# 6   대전  8,098  8,502  9,056  9,589
# 7   부산 10,307 10,430 11,664 12,710
# 8   서울 19,725 20,663 21,425 22,299
# 9   세종  8,750  8,860  9,133 10,382
# 10  울산 10,053 10,209 11,328 10,441
# 11  인천 10,484 10,532 10,749 11,218
# 12  전남  6,317  6,489  7,246  7,794
# 13  전북  6,703  6,418  7,075  7,552
# 14  제주  7,405  9,129 10,907 12,741
# 15  충남  7,115  7,331  7,456  7,973
# 16  충북  6,645  6,770  6,770  7,893

# %%
region_year["변동액"] = (region_year['2018'] - region_year['2015']).astype(int)

max_price = np.max(region_year['변동액']) * 1000
min_price = np.min(region_year['변동액']) * 1000
mean_price = np.mean(region_year['변동액']) * 1000

print("2015 ~ 2018 분양가는 상승하였다.")
print("2015 ~ 2018 상승액이 가장 큰 곳은 제주, 평당 {:,.0f}원이다.".format(max_price))
print("2015 ~ 2018 상승액이 가장 작은 곳은 울산, 평당 {:,.0f}원이다.".format(min_price))
print("2015 ~ 2018 전국 평균 변동액은 평당 {:,.0f}원이다.".format(mean_price))
# Out:
# 2015 ~ 2018 분양가는 상승하였다.
# 2015 ~ 2018 상승액이 가장 큰 곳은 제주, 평당 5,335,000원이다.
# 2015 ~ 2018 상승액이 가장 작은 곳은 울산, 평당 387,000원이다.
# 2015 ~ 2018 전국 평균 변동액은 평당 1,666,647원이다.

# %% [markdown]
# # 연도별 변동 그래프

# %%
(ggplot(region_year_all, aes(x='지역명', y='평당분양가격', fill='연도'))
 + geom_bar(stat='identity', position='dodge')
 + ggtitle('2015-2018년 신규 민간 아파트 분양가격')
 + theme(text=element_text(fontproperties=font), figure_size=(8, 4))
)
# Out:
# <ggplot: (-9223372029832783251)>

# %% [markdown]
# # 지역별 평당 분양가격 합계

# %%
data_1806.pivot_table('평당분양가격', '규모구분', '지역명')
# Out:
# 지역명                  강원     경기    경남    경북     광주     대구     대전     부산     서울  \
# 규모구분
# 전용면적 102㎡초과       7,907 13,592 9,226 8,624 10,347 12,308 14,282 12,591 22,055
# 전용면적 60㎡이하        7,191 12,300 8,340 7,655  8,518 11,259  8,818 10,705 22,003
# 전용면적 60㎡초과 85㎡이하  7,228 11,649 8,101 7,663  9,170 10,924  8,789 11,176 20,680
# 전용면적 85㎡초과 102㎡이하 7,601 12,029 9,828 8,776  9,296  9,497  9,078 11,010 23,726
# 전체                7,198 11,666 8,129 7,668  9,163 10,891  8,864 11,282 21,153
#
# 지역명                  세종     울산     인천    전남    전북     제주    충남    충북
# 규모구분
# 전용면적 102㎡초과       9,259  9,941 13,902 7,570 7,801 10,435 8,448 7,911
# 전용면적 60㎡이하        9,072  8,989 10,857 7,005 7,192 14,813 7,777 6,961
# 전용면적 60㎡초과 85㎡이하  9,229 10,666 10,725 6,969 6,880  9,955 7,484 7,013
# 전용면적 85㎡초과 102㎡이하 9,210  8,861 11,288 7,849 7,739 10,744 9,102 8,125
# 전체                9,226 10,644 10,732 6,986 6,889 10,276 7,473 6,963

# %% [markdown]
# ## - 규모별

# %%
(ggplot(data_1806, aes(x='지역명', y='평당분양가격', fill='규모구분'))
 + geom_bar(stat='identity', position='dodge')
 + ggtitle('규모별 신규 민간 아파트 분양가격')
 + theme(text=element_text(fontproperties=font), figure_size=(8, 4)))
# Out:
# <ggplot: (7021571364)>

# %%
(ggplot(data_1806, aes(x='연도', y='평당분양가격', fill='규모구분')) 
 + geom_bar(stat='identity', position='dodge')
 + facet_wrap('지역명')
 + theme(text=element_text(fontproperties=font), 
         axis_text_x=element_text(rotation=70),
         figure_size=(8, 8)))
# Out:
# <ggplot: (7023739477)>

# %%
(ggplot(data_1806, aes(x='지역명', y='평당분양가격', fill='규모구분'))
 + geom_boxplot()
 + ggtitle('전국 규모별 신규 민간 아파트 분양가격')
 + theme(text=element_text(fontproperties=font), 
         figure_size=(12, 6)))
# Out:
# <ggplot: (-9223372029830970592)>

# %%
(ggplot(data_1806.loc[data_1806['지역명'] == '서울'])
 + aes(x='연도', y='평당분양가격', fill='규모구분')
 + geom_boxplot()
 + ggtitle('서울 연도/규모별 신규 민간 아파트 분양가격')
 + theme(text=element_text(fontproperties=font)))
# Out:
# <ggplot: (7025595207)>

# %%
# 분양가 차이가 가장 컷던 제주
(ggplot(data_1806.loc[data_1806['지역명'] == '제주'])
 + aes(x='연도', y='평당분양가격', fill='규모구분')
 + geom_boxplot()
 + ggtitle('제주 연도/규모별 신규 민간 아파트 분양가격')
 + theme(text=element_text(fontproperties=font)))
# Out:
# <ggplot: (-9223372029832637005)>

# %%
# 분양가 차이가 가장 작았던 울산
(ggplot(data_1806.loc[data_1806['지역명']=='울산'])
 + aes(x='연도', y='평당분양가격', fill='규모구분')
 + geom_boxplot()
 + ggtitle('울산 연도/규모별 신규 민간 아파트 분양가격')
 + theme(text=element_text(fontproperties=font)))
# Out:
# <ggplot: (7025254478)>

# %% [markdown]
# # Data Load

# %%
data_1509 = pd.read_csv("data/2013_09_2015_09_national_avg_pirce.csv", encoding='euc-kr', skiprows=1, header=0)
print(data_1509.shape)
# Out:
# (23, 27)

# %%
data_1509.head()
# Out:
#   Unnamed: 0 Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0         구분        NaN        2013        2014         nan         nan
# 1         시도        시군구          12           1           2           3
# 2         전국        NaN        8059        8130       8,195       8,204
# 3         서울        NaN       18189       17925      17,925      18,016
# 4      6대광역시         부산        8111        8111       9,078       8,965
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 17  \
# 0         nan         nan         nan         nan  ...          nan
# 1           4           5           6           7  ...            3
# 2       8,289       8,358       8,344       8,333  ...        8,563
# 3      18,098      19,446      18,867      18,742  ...       19,415
# 4       9,402       9,501       9,453       9,457  ...        9,279
#
#    Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  \
# ...

# %%
year = data_1509.iloc[0]
month = data_1509.iloc[1]

# %%
year
# Out:
# Unnamed: 0                구분
# Unnamed: 1               NaN
# Unnamed: 2              2013
# Unnamed: 3              2014
# Unnamed: 4               NaN
# Unnamed: 5               NaN
# Unnamed: 6               NaN
# Unnamed: 7               NaN
# Unnamed: 8               NaN
# Unnamed: 9               NaN
# Unnamed: 10              NaN
# Unnamed: 11              NaN
# Unnamed: 12              NaN
# Unnamed: 13              NaN
# Unnamed: 14              NaN
# Unnamed: 15             2015
# Unnamed: 16              NaN
# Unnamed: 17              NaN
# Unnamed: 18              NaN
# Unnamed: 19              NaN
# Unnamed: 20              NaN
# Unnamed: 21              NaN
# Unnamed: 22              NaN
# Unnamed: 23              NaN
# Unnamed: 24              NaN
# Unnamed: 25              NaN
# Unnamed: 26    (단위: 천원/3.3㎡)
# Name: 0, dtype: object

# %%
month
# Out:
# Unnamed: 0        시도
# Unnamed: 1       시군구
# Unnamed: 2        12
# Unnamed: 3         1
# Unnamed: 4         2
# Unnamed: 5         3
# Unnamed: 6         4
# Unnamed: 7         5
# Unnamed: 8         6
# Unnamed: 9         7
# Unnamed: 10        8
# Unnamed: 11        9
# Unnamed: 12       10
# Unnamed: 13       11
# Unnamed: 14       12
# Unnamed: 15        1
# Unnamed: 16        2
# Unnamed: 17        3
# Unnamed: 18        4
# Unnamed: 19        5
# Unnamed: 20        6
# Unnamed: 21        7
# Unnamed: 22        8
# Unnamed: 23        9
# Unnamed: 24      전월비
# Unnamed: 25     전년말비
# Unnamed: 26    전년동월비
# Name: 1, dtype: object

# %%
# 0과 1번째 행 합치기
for i, y in enumerate(year):
    if i > 2 and i < 15:
        year[i] = '2014년 ' + str(int(month[i])) + '월'
    elif i >= 15 and i < 24:
        year[i] = '2015년 ' + str(int(month[i])) + '월'
    elif i >= 24:
        year[i] = month[i]
    elif i == 1:
        year[i] = '시군구'
    elif i == 2:
        year[i] = '2013년 12월'
print(year)
# Out:
# Unnamed: 0            구분
# Unnamed: 1           시군구
# Unnamed: 2     2013년 12월
# Unnamed: 3      2014년 1월
# Unnamed: 4      2014년 2월
# Unnamed: 5      2014년 3월
# Unnamed: 6      2014년 4월
# Unnamed: 7      2014년 5월
# Unnamed: 8      2014년 6월
# Unnamed: 9      2014년 7월
# Unnamed: 10     2014년 8월
# Unnamed: 11     2014년 9월
# Unnamed: 12    2014년 10월
# Unnamed: 13    2014년 11월
# Unnamed: 14    2014년 12월
# Unnamed: 15     2015년 1월
# Unnamed: 16     2015년 2월
# Unnamed: 17     2015년 3월
# Unnamed: 18     2015년 4월
# Unnamed: 19     2015년 5월
# Unnamed: 20     2015년 6월
# Unnamed: 21     2015년 7월
# Unnamed: 22     2015년 8월
# Unnamed: 23     2015년 9월
# Unnamed: 24          전월비
# Unnamed: 25         전년말비
# Unnamed: 26        전년동월비
# Name: 0, dtype: object

# %%
data_1509.columns = year
data_1509.head()
# Out:
# 0     구분  시군구  2013년 12월  2014년 1월  2014년 2월  2014년 3월  2014년 4월  2014년 5월  \
# 0     구분  NaN       2013      2014       nan       nan       nan       nan
# 1     시도  시군구         12         1         2         3         4         5
# 2     전국  NaN       8059      8130     8,195     8,204     8,289     8,358
# 3     서울  NaN      18189     17925    17,925    18,016    18,098    19,446
# 4  6대광역시   부산       8111      8111     9,078     8,965     9,402     9,501
#
# 0  2014년 6월  2014년 7월  ...  2015년 3월  2015년 4월  2015년 5월  2015년 6월  2015년 7월  \
# 0       nan       nan  ...       nan       nan       nan       nan       nan
# 1         6         7  ...         3         4         5         6         7
# 2     8,344     8,333  ...     8,563     8,613     8,624     8,627     8,643
# 3    18,867    18,742  ...    19,415    18,842    18,367    18,374    18,152
# 4     9,453     9,457  ...     9,279     9,327     9,345     9,515     9,559
#
# 0  2015년 8월  2015년 9월   전월비   전년말비          전년동월비
# ...

# %%
data_1509 = data_1509.drop(data_1509.index[[0, 1]])
data_1509
# Out:
# 0      구분  시군구  2013년 12월  2014년 1월  2014년 2월  2014년 3월  2014년 4월  2014년 5월  \
# 2      전국  NaN       8059      8130     8,195     8,204     8,289     8,358
# 3      서울  NaN      18189     17925    17,925    18,016    18,098    19,446
# 4   6대광역시   부산       8111      8111     9,078     8,965     9,402     9,501
# 5     NaN   대구       8080      8080     8,077     8,101     8,267     8,274
# 6     NaN   인천      10204     10204    10,408    10,408    10,000     9,844
# 7     NaN   광주       6098      7326     7,611     7,346     7,346     7,523
# 8     NaN   대전       8321      8321     8,321     8,341     8,341     8,341
# 9     NaN   울산       8090      8090     8,090     8,153     8,153     8,153
# 10    NaN  NaN       8151      8355     8,597     8,552     8,585     8,606
# 11     경기  NaN      10855     10855    10,791    10,784    10,876    10,646
# 12    수도권  NaN      13083     12995    13,041    13,069    12,991    13,312
# ...

# %%
data_1509['구분'] = data_1509['구분'].fillna('')
data_1509['시군구'] = data_1509['시군구'].fillna('')
data_1509.head()
# Out:
# 0     구분 시군구  2013년 12월  2014년 1월  2014년 2월  2014년 3월  2014년 4월  2014년 5월  \
# 2     전국           8059      8130     8,195     8,204     8,289     8,358
# 3     서울          18189     17925    17,925    18,016    18,098    19,446
# 4  6대광역시  부산       8111      8111     9,078     8,965     9,402     9,501
# 5         대구       8080      8080     8,077     8,101     8,267     8,274
# 6         인천      10204     10204    10,408    10,408    10,000     9,844
#
# 0  2014년 6월  2014년 7월  ...  2015년 3월  2015년 4월  2015년 5월  2015년 6월  2015년 7월  \
# 2     8,344     8,333  ...     8,563     8,613     8,624     8,627     8,643
# 3    18,867    18,742  ...    19,415    18,842    18,367    18,374    18,152
# 4     9,453     9,457  ...     9,279     9,327     9,345     9,515     9,559
# 5     8,360     8,360  ...     8,441     8,446     8,568     8,542     8,542
# 6    10,058     9,974  ...     9,876     9,938    10,551    10,443    10,443
#
# 0  2015년 8월  2015년 9월   전월비   전년말비  전년동월비
# ...

# %%
data_1509['지역'] = data_1509['구분'] + data_1509['시군구']
data_1509['지역'].head()
# Out:
# 2         전국
# 3         서울
# 4    6대광역시부산
# 5         대구
# 6         인천
# Name: 지역, dtype: object

# %%
melt_columns = data_1509.columns.copy()
melt_columns
# Out:
# Index(['구분', '시군구', '2013년 12월', '2014년 1월', '2014년 2월', '2014년 3월',
#        '2014년 4월', '2014년 5월', '2014년 6월', '2014년 7월', '2014년 8월', '2014년 9월',
#        '2014년 10월', '2014년 11월', '2014년 12월', '2015년 1월', '2015년 2월',
#        '2015년 3월', '2015년 4월', '2015년 5월', '2015년 6월', '2015년 7월', '2015년 8월',
#        '2015년 9월', '전월비', '전년말비', '전년동월비', '지역'],
#       dtype='object', name=0)

# %%
# 옆으로 붙일 때는 merge 아래로 붙일 때는 concat
data_1509_melt = pd.melt(data_1509, id_vars=['지역'], value_vars=['2013년 12월', '2014년 1월', 
       '2014년 2월', '2014년 3월', '2014년 4월', '2014년 5월', '2014년 6월', '2014년 7월', '2014년 8월', 
       '2014년 9월','2014년 10월', '2014년 11월', '2014년 12월', '2015년 1월', '2015년 2월','2015년 3월', 
       '2015년 4월', '2015년 5월', '2015년 6월', '2015년 7월', '2015년 8월','2015년 9월'])

data_1509_melt.head()
# Out:
#         지역          0  value
# 0       전국  2013년 12월  8,059
# 1       서울  2013년 12월 18,189
# 2  6대광역시부산  2013년 12월  8,111
# 3       대구  2013년 12월  8,080
# 4       인천  2013년 12월 10,204

# %%
data_1806.head()
# Out:
#   지역명               규모구분    연도   월  분양가격(㎡)  평당분양가격
# 0  서울                 전체  2015  10    5,841  19,275
# 1  서울         전용면적 60㎡이하  2015  10    5,652  18,652
# 2  서울   전용면적 60㎡초과 85㎡이하  2015  10    5,882  19,411
# 3  서울  전용면적 85㎡초과 102㎡이하  2015  10    5,721  18,879
# 4  서울        전용면적 102㎡초과  2015  10    5,879  19,401

# %%
data_1509_melt.columns = ['지역명', '기간', '분양가격']
data_1509_melt.head()
# Out:
#        지역명         기간   분양가격
# 0       전국  2013년 12월  8,059
# 1       서울  2013년 12월 18,189
# 2  6대광역시부산  2013년 12월  8,111
# 3       대구  2013년 12월  8,080
# 4       인천  2013년 12월 10,204

# %%
data_1509_melt['연도'] = data_1509_melt['기간'].apply(lambda year_month : year_month.split('년')[0])
data_1509_melt['월'] = data_1509_melt['기간'].apply(lambda year_month : re.sub('월', '', year_month.split('년')[1]).strip())

data_1509_melt.head()
# Out:
#        지역명         기간   분양가격    연도   월
# 0       전국  2013년 12월  8,059  2013  12
# 1       서울  2013년 12월 18,189  2013  12
# 2  6대광역시부산  2013년 12월  8,111  2013  12
# 3       대구  2013년 12월  8,080  2013  12
# 4       인천  2013년 12월 10,204  2013  12

# %%
data_1509_melt['지역명'].value_counts()
# Out:
#            44
# 인천         22
# 전남         22
# 충북         22
# 전국         22
# 6대광역시부산    22
# 경기         22
# 대구         22
# 대전         22
# 세종         22
# 충남         22
# 광주         22
# 제주         22
# 울산         22
# 지방강원       22
# 전북         22
# 수도권        22
# 경남         22
# 서울         22
# 경북         22
# Name: 지역명, dtype: int64

# %%
data_1509_melt['지역명'] = data_1509_melt['지역명'].apply(lambda x: re.sub('6대광역시부산','부산', x))
data_1509_melt['지역명'] = data_1509_melt['지역명'].apply(lambda x: re.sub('지방강원','강원', x))
data_1509_melt.describe()
# Out:
#         분양가격
# count    462
# mean   8,611
# std    2,868
# min    5,609
# 25%    6,754
# 50%    8,067
# 75%    8,980
# max   20,670

# %%
data_1509_melt['지역명'].value_countsnts()
# Out:
#        44
# 인천     22
# 전남     22
# 충북     22
# 전국     22
# 경기     22
# 대구     22
# 대전     22
# 세종     22
# 부산     22
# 충남     22
# 제주     22
# 울산     22
# 강원     22
# 경북     22
# 전북     22
# 수도권    22
# 경남     22
# 서울     22
# 광주     22
# Name: 지역명, dtype: int64
